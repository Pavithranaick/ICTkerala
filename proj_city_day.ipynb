# %% [markdown]
# Importing required libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# 1 Data Collection

# %% [markdown]
# Reading the dataset to the python environment and understanding data

# %%
data=pd.read_csv('city_day.csv')
data.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
data.tail()
# Out:
#                 City        Date  PM2.5   PM10    NO    NO2    NOx    NH3  \
# 29526  Visakhapatnam  2020-06-27  15.02  50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97  4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00  0.40  26.85  14.05   5.20
#
#          CO    SO2     O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 29526  0.47   8.55  23.30     2.24    12.07    0.73  41.0          Good
# 29527  0.52  12.72  30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528  0.48   8.42  30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529  0.52   9.84  28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530  0.59   2.10  17.05      NaN      NaN     NaN  50.0          Good

# %%
data.shape
# Out:
# (29531, 16)

# %%
data.dtypes
# Out:
# City           object
# Date           object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
data.describe().T
# Out:
#            count        mean         std    min     25%     50%       75%  \
# PM2.5    24933.0   67.450578   64.661449   0.04  28.820   48.57   80.5900
# PM10     18391.0  118.127103   90.605110   0.01  56.255   95.68  149.7450
# NO       25949.0   17.574730   22.785846   0.02   5.630    9.89   19.9500
# NO2      25946.0   28.560659   24.474746   0.01  11.750   21.69   37.6200
# NOx      25346.0   32.309123   31.646011   0.00  12.820   23.52   40.1275
# NH3      19203.0   23.483476   25.684275   0.01   8.580   15.85   30.0200
# CO       27472.0    2.248598    6.962884   0.00   0.510    0.89    1.4500
# SO2      25677.0   14.531977   18.133775   0.01   5.670    9.16   15.2200
# O3       25509.0   34.491430   21.694928   0.01  18.860   30.84   45.5700
# Benzene  23908.0    3.280840   15.811136   0.00   0.120    1.07    3.0800
# Toluene  21490.0    8.700972   19.969164   0.00   0.600    2.97    9.1500
# Xylene   11422.0    3.070128    6.323247   0.00   0.140    0.98    3.3500
# ...

# %% [markdown]
# 2 EDA

# %% [markdown]
# Visualizing the data

# %%
fig=plt.figure(figsize=(20,10))
ax=fig.gca()
data.hist(ax=ax)
#data.hist()
#plt.show()
# Out:
# <ipython-input-13-a5cf6ece0bab>:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   data.hist(ax=ax)
# array([[<AxesSubplot:title={'center':'PM2.5'}>,
#         <AxesSubplot:title={'center':'PM10'}>,
#         <AxesSubplot:title={'center':'NO'}>,
#         <AxesSubplot:title={'center':'NO2'}>],
#        [<AxesSubplot:title={'center':'NOx'}>,
#         <AxesSubplot:title={'center':'NH3'}>,
#         <AxesSubplot:title={'center':'CO'}>,
#         <AxesSubplot:title={'center':'SO2'}>],
#        [<AxesSubplot:title={'center':'O3'}>,
#         <AxesSubplot:title={'center':'Benzene'}>,
#         <AxesSubplot:title={'center':'Toluene'}>,
#         <AxesSubplot:title={'center':'Xylene'}>],
#        [<AxesSubplot:title={'center':'AQI'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
#converting column Date into DateTime format
#data['Date']=pd.to_datetime(data['Date'])

#extracting year and month for each record
data['year'] = pd.DatetimeIndex(data['Date']).year
data['month'] = pd.DatetimeIndex(data['Date']).month

# %%
data.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket  year  month
# 0  133.36     0.00     0.02    0.00  NaN        NaN  2015      1
# 1   34.06     3.68     5.50    3.77  NaN        NaN  2015      1
# 2   30.70     6.80    16.40    2.25  NaN        NaN  2015      1
# 3   36.08     4.43    10.14    1.00  NaN        NaN  2015      1
# 4   39.31     7.01    18.89    2.78  NaN        NaN  2015      1

# %%
pollutants = ['PM2.5','PM10', 'NO', 'NOx','NO2','CO','NH3','O3','SO2']
df = data.set_index('Date')
axes = df[pollutants].plot(marker='.',alpha = 0.5, linestyle = 'None', figsize = (16,20), subplots = True)
for ax in axes:
    ax.set_xlabel('Years')
    ax.set_ylabel('ug/m3')

# %% [markdown]
# Observations:
#
# ->PM2.5, O3 are usually high throughout the year
#
# ->CO has been found consistently low over the years

# %%
plt.title('Distribution of AQI Buckets 2015-2020')
sns.countplot(x='AQI_Bucket', data=data, hue='year')
# Out:
# <AxesSubplot:title={'center':'Distribution of AQI Buckets 2015-2020'}, xlabel='AQI_Bucket', ylabel='count'>

# %%
#Grouping the AQI by city and calculating the average AQI per city
x=pd.DataFrame(data.groupby(['City'])[['AQI']].mean().sort_values(by='AQI',ascending=False).head(10))
x=x.reset_index('City')

#plotting the average AQI per city
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(10,5))
sns.barplot(data=x,x='AQI',y='City',orient='h',palette='viridis')
# Out:
# <AxesSubplot:xlabel='AQI', ylabel='City'>

# %% [markdown]
# Observation:

# %%
#plotting the average AQI over the years for top 5 cities which have AQI greater than 500

data['City'][data['AQI']>=500].value_counts()

cols=['Ahmedabad','Delhi','Patna','Gurugram','Lucknow']

for col in cols:
    plt.figure(figsize=(5,5))

    x=data[data['City']==col]
    sns.barplot(x='year',y='AQI',data=x)
    plt.title(col)

# %% [markdown]
# Observation:

# %%
x=pd.DataFrame(data['City'][data['AQI']< 50].value_counts().head(10))
x=x.rename(columns={'City':'Count'})

plt.figure(figsize=(10,5))
sns.barplot(x='Count',y=x.index,data=x,palette='viridis_r')
# Out:
# <AxesSubplot:xlabel='Count'>

# %% [markdown]
# Observations:Bar plot illustrating which of the cities have AQI less than 50 and plotting their value count.From this we can infer which of the cities have a relatively good air quality,Amaravati and Hyderabad having top in good air quality and so on..

# %%
## AQI
print(f"Minimum and maximum range of AQI: {data.AQI.min()} - {data.AQI.max()}")
plt.title('AQI levels over 2015 to 2020')
sns.lineplot(x='year',y='AQI', data=data)
# Out:
# Minimum and maximum range of AQI: 13.0 - 2049.0
# <AxesSubplot:title={'center':'AQI levels over 2015 to 2020'}, xlabel='year', ylabel='AQI'>

# %%
df = data[data['year'] == 2020]
plt.title('AQI Levels in the year 2020')
sns.lineplot(x='month', y='AQI', data=df);

# %%
df = data[data['year'] == 2019]
plt.title('AQI Levels in the year 2020')
sns.lineplot(x='month', y='AQI', data=df);

# %%
data = data[(data['year'] == '2019') | (data['year'] == '2020')]
plt.title('AQI Levels in year 2019-2020')
sns.lineplot(x='month',y='AQI', data=data);
